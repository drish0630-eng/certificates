# %% [markdown]
# <h1 align="center">
#     NSDC Data Science Projects
# </h1>
#
# <h2 align="center">
#     Project: Practicing Writing SQL Queries - #1
# </h2>
#
# <h3 align="center">
#     Name: Drishtant Dash
# </h3>

# %% [markdown]
# ### **Please read before you begin your project**
#
# **Instructions: Google Colab Notebooks:**
#
# Google Colab is a free cloud service. It is a hosted Jupyter notebook service that requires no setup to use, while providing free access to computing resources. We will be using Google Colab for this project.
#
# In order to work within the Google Colab Notebook, **please start by clicking on "File" and then "Save a copy in Drive."** This will save a copy of the notebook in your personal Google Drive.
#
# Please rename the file to "DSP - SQL Queries #1 - Your Full Name." Once this project is completed, you will be prompted to share your file with the National Student Data Corps (NSDC) Project Leaders.
#
# You can now start working on the project. :)
#
# **Project Description:**
#
# To work with the New York City Airbnb dataset in this project, you'll need to create and connect to an SQLite database as seen in the steps within this notebook.
#
# **Key Features**
#
# - Practical SQL exercises with step-by-step instructions.
# - Real-world datasets for hands-on experience.
# - Comprehensive explanations of SQL queries and concepts.
# - Interactive coding examples and challenges.
#
# **Dataset**
# - You can find the New York City Airbnb dataset on Kaggle: [New York City Airbnb Dataset](https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data)
# - Download the dataset from the provided link and save it as 'AB_NYC_2019.csv' on your computer.
# - On Google Colab, click on the "Upload" button and select the 'AB_NYC_2019.csv' file from your local computer.

# %% [markdown]
# ## Introduction
# This SQL project is designed for beginners who want to practice writing SQL queries using a real-world dataset. In this project, we will work with the New York City Airbnb dataset. The main goal is to help you become familiar with SQL syntax and basic data analysis tasks. Make sure to complete the code where there is a 'TODO' sign. Hints are provided along the way.
#
# ## Table of Contents
# 1. [Libraries and Database Setup](#database-setup)
# 2. [Loading the Dataset](#loading-dataset)
# 3. [SQL Queries](#sql-queries)
# 4. [Closing Connection](#closing-connection)
# 5. [Summary of Basic SQL Commands](#summary-commands)
#
# # Section 1: Libraries and Database Setup <a name="database-setup"></a>
#
# ### Task 1.1: Import Libraries
# Let's start by importing the necessary libraries.

# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# ### Task 1.2: Connect to the Database
#
# Next, establish a connection to the SQLite database named 'airbnb.db'.
# Use the sqlite3 library to create a connection object and store it in a variable called 'conn'.

# %%
# Completed
# Connect to the SQLite database
conn = sqlite3.connect('airbnb.db')

# %% [markdown]
# # Section 2: Loading the Dataset <a name="loading-dataset"></a>

# %% [markdown]
# ### Task 2.1: Load the Dataset
# - You will work with the 'listings' table from the New York City Airbnb dataset.
# - Load the dataset from the CSV file 'AB_NYC_2019.csv' into a DataFrame named 'df'.
# - Then, import the DataFrame into the 'listings' table in the database using the to_sql() method.
#
# Hint: Use the read_csv() method from pandas to read the CSV file.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TODO: Load the dataset into the SQLite database
import pandas as pd
import sqlite3

path = "/content/drive/MyDrive/AB_NYC_2019.csv"

df = pd.read_csv(path)
conn = sqlite3.connect("airbnb.db")


#Completed
df.to_sql('listings', conn, if_exists='replace', index=False)
# Out:
# 48895

# %% [markdown]
# # Section 3: SQL Queries <a name="sql-queries"></a>
#
# Query the database: Write SQL queries to analyze the data in the SQLite database. You can use the sqlite3 library to execute the queries and fetch the results.

# %% [markdown]
# ### Task 3.1: Retrieve all Columns
# - Write an SQL query to retrieve all columns from the 'listings' table.
# - Execute the query and display the first 10 rows of the result
#
# Hint: Use SELECTION to select entries from a specified table.

# %%
cursor = conn.cursor()

# TODO: Execute an SQL query using the cursor.execute() method to retrieve all columns from listings (don't forget the trailing ';' to finish a query)
cursor.execute("SELECT * FROM listings;")

# Completed
# Fetch all the results using fetchall()
results = cursor.fetchall()

# %%
# TODO: Display the first 10 rows
for i, row in enumerate(results[:10]):
    print(row)
# Out:
# (2539, 'Clean & quiet apt home by the park', 2787, 'John', 'Brooklyn', 'Kensington', 40.64749, -73.97237, 'Private room', 149, 1, 9, '2018-10-19', 0.21, 6, 365)
# (2595, 'Skylit Midtown Castle', 2845, 'Jennifer', 'Manhattan', 'Midtown', 40.75362, -73.98377, 'Entire home/apt', 225, 1, 45, '2019-05-21', 0.38, 2, 355)
# (3647, 'THE VILLAGE OF HARLEM....NEW YORK !', 4632, 'Elisabeth', 'Manhattan', 'Harlem', 40.80902, -73.9419, 'Private room', 150, 3, 0, None, None, 1, 365)
# (3831, 'Cozy Entire Floor of Brownstone', 4869, 'LisaRoxanne', 'Brooklyn', 'Clinton Hill', 40.68514, -73.95976, 'Entire home/apt', 89, 1, 270, '2019-07-05', 4.64, 1, 194)
# (5022, 'Entire Apt: Spacious Studio/Loft by central park', 7192, 'Laura', 'Manhattan', 'East Harlem', 40.79851, -73.94399, 'Entire home/apt', 80, 10, 9, '2018-11-19', 0.1, 1, 0)
# (5099, 'Large Cozy 1 BR Apartment In Midtown East', 7322, 'Chris', 'Manhattan', 'Murray Hill', 40.74767, -73.975, 'Entire home/apt', 200, 3, 74, '2019-06-22', 0.59, 1, 129)
# (5121, 'BlissArtsSpace!', 7356, 'Garon', 'Brooklyn', 'Bedford-Stuyvesant', 40.68688, -73.95596, 'Private room', 60, 45, 49, '2017-10-05', 0.4, 1, 0)
# (5178, "Large Furnished Room Near B'way ", 8967, 'Shunichi', 'Manhattan', "Hell's Kitchen", 40.76489, -73.98493, 'Private room', 79, 2, 430, '2019-06-24', 3.47, 1, 220)
# (5203, 'Cozy Clean Guest Room - Family Apt', 7490, 'MaryEllen', 'Manhattan', 'Upper West Side', 40.80178, -73.96723, 'Private room', 79, 2, 118, '2017-07-21', 0.99, 1, 0)
# (5238, 'Cute & Cozy Lower East Side 1 bdrm', 7549, 'Ben', 'Manhattan', 'Chinatown', 40.71344, -73.99037, 'Entire home/apt', 150, 1, 160, '2019-06-09', 1.33, 4, 188)

# %% [markdown]
# ### Task 3.2: Count Total Records
# - Write an SQL query to count the total number of records in the 'listings' table.
# - Execute the query and display the count.
#
# Hint: This query uses the COUNT(*) function to count the total number of records in the "listings" table.

# %%
# TODO: Execute the SQL query to count the number of records (don't forget the trailing ';' to finish a query)
cursor.execute("SELECT COUNT(*) from listings;")

# Completed
count = cursor.fetchone()[0]
# Print the count
print("Total number of records in the 'listings' table:", count)
# Out:
# Total number of records in the 'listings' table: 48895

# %% [markdown]
# ### Task 3.3: Top 10 Neighborhoods by Average Price
# - Write an SQL query to find the top 10 neighborhoods with the highest average listing price.
# - Execute the query and display the results.
#
# Hint: The result includes the neighborhood group, neighborhood name, and the average price. Make sure to use GROUP BY and ORDER BY, respectively.

# %%
# TODO: Execute the SQL query to find the top 10 neighborhoods with the highest average listing price (finish the two missing sql commands)
cursor.execute("""
    SELECT neighbourhood_group, neighbourhood, AVG(price) AS avg_price
    FROM listings
    Group By neighbourhood_group, neighbourhood
    Order By avg_price desc
    LIMIT 10;
""")

# Completed
results = cursor.fetchall()

# %%
# Display the results
for row in results:
    print(row)
# Out:
# ('Staten Island', 'Fort Wadsworth', 800.0)
# ('Staten Island', 'Woodrow', 700.0)
# ('Manhattan', 'Tribeca', 490.638418079096)
# ('Brooklyn', 'Sea Gate', 487.85714285714283)
# ('Bronx', 'Riverdale', 442.09090909090907)
# ('Staten Island', "Prince's Bay", 409.5)
# ('Manhattan', 'Battery Park City', 367.5571428571429)
# ('Manhattan', 'Flatiron District', 341.925)
# ('Staten Island', 'Randall Manor', 336.0)
# ('Manhattan', 'NoHo', 295.71794871794873)

# %% [markdown]
# ### Task 3.4: Number of Listings by Room Type
# - Write an SQL query to determine the number of listings available for each room type.
# - Execute the query and display the results.
#
# Hint: The COUNT(*) function is used to count the number of records for each room type, and the result is grouped by the room type.

# %%
# TODO: Execute the SQL query to determine the number of listings available for each room type (finish the one missing sql command)
cursor.execute("""
    SELECT room_type, COUNT(*) AS num_listings
    FROM listings
    GROUP BY room_type;
""")

# Completed
results = cursor.fetchall()

# %%
# Display the results
for row in results:
    print(row)
# Out:
# ('Entire home/apt', 25409)
# ('Private room', 22326)
# ('Shared room', 1160)

# %% [markdown]
# ### Task 3.5: Average Number of Reviews per Listing
# - Write an SQL query to calculate the average number of reviews per listing.
# - Execute the query and display the average.
#
# Hint: Use AVG() to find the average of a column and save it via an alias using AS. Make sure to specify the table using FROM.

# %%
# TODO: Execute the SQL query to calculate the average number of reviews per listing (finish both the missing sql commands)
cursor.execute("""
    SELECT AVG(number_of_reviews) AS avg_reviews
    From listings;
""")

# Completed
result = cursor.fetchone()
# Print the average number of reviews per listing
print("Average number of reviews per listing:", result[0])
# Out:
# Average number of reviews per listing: 23.274465691788528

# %% [markdown]
# ### Task 3.6: Listings with Minimum Number of Reviews
# - Write an SQL query to find the listings with the minimum number of reviews.
# - Execute the query and display the results (limit to 15 rows).
#
# Hint: The subquery (SELECT MIN(number_of_reviews) FROM listings) retrieves the minimum number of reviews from the "listings" table, and the main query filters the rows where number_of_reviews matches the minimum value. Make sure to use WHERE clause.

# %%
# TODO: Execute the SQL query to find the listings with the minimum number of reviews (finish the third missing sql command)
cursor.execute("""
    SELECT id
    FROM listings
    WHERE number_of_reviews = (
          SELECT min (number_of_reviews)
          From listings)

    LIMIT 15;
""")

# Completed
results = cursor.fetchall()

# %%
# Display the results (limit to 15 rows)
for row in results:
    print(row)
# Out:
# (3647,)
# (7750,)
# (8700,)
# (11452,)
# (11943,)
# (51438,)
# (54466,)
# (63588,)
# (63913,)
# (64015,)
# (65556,)
# (89427,)
# (94209,)
# (118680,)
# (145188,)

# %% [markdown]
# ### Task 3.7: Filter Listings by Neighborhood and Maximum Price
# - Write an SQL query to filter the listings in the 'Chelsea' neighborhood with a maximum price of $200.
# - Execute the query and display the results.
#
# Hint: The WHERE clause is used to specify the filtering conditions.

# %%
# TODO: Execute the SQL query to filter the listings
cursor.execute("""
    SELECT id, neighbourhood, neighbourhood_group, room_type, price
    FROM listings
    WHERE neighbourhood = 'Chelsea' AND price <= 200
""")

# Completed
results = cursor.fetchall()

# %%
# Display the results
for row in results:
    print(row)
# Out:
# (7322, 'Chelsea', 'Manhattan', 'Private room', 140)
# (18728, 'Chelsea', 'Manhattan', 'Private room', 150)
# (21794, 'Chelsea', 'Manhattan', 'Private room', 98)
# (47370, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (51572, 'Chelsea', 'Manhattan', 'Private room', 123)
# (98663, 'Chelsea', 'Manhattan', 'Entire home/apt', 130)
# (135706, 'Chelsea', 'Manhattan', 'Entire home/apt', 132)
# (145188, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (159913, 'Chelsea', 'Manhattan', 'Private room', 150)
# (193853, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (222304, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (258690, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (261674, 'Chelsea', 'Manhattan', 'Private room', 95)
# (442649, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (456110, 'Chelsea', 'Manhattan', 'Entire home/apt', 139)
# (502132, 'Chelsea', 'Manhattan', 'Shared room', 50)
# (515392, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (516461, 'Chelsea', 'Manhattan', 'Entire home/apt', 130)
# (522081, 'Chelsea', 'Manhattan', 'Private room', 170)
# (525120, 'Chelsea', 'Manhattan', 'Entire home/apt', 135)
# (564184, 'Chelsea', 'Manhattan', 'Private room', 125)
# (649561, 'Chelsea', 'Manhattan', 'Entire home/apt', 135)
# (667375, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (683084, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (698327, 'Chelsea', 'Manhattan', 'Private room', 72)
# (731316, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (747029, 'Chelsea', 'Manhattan', 'Private room', 155)
# (767967, 'Chelsea', 'Manhattan', 'Entire home/apt', 105)
# (812938, 'Chelsea', 'Manhattan', 'Entire home/apt', 99)
# (823520, 'Chelsea', 'Manhattan', 'Private room', 179)
# (826764, 'Chelsea', 'Manhattan', 'Private room', 65)
# (841292, 'Chelsea', 'Manhattan', 'Private room', 109)
# (858223, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (919830, 'Chelsea', 'Manhattan', 'Private room', 125)
# (925137, 'Chelsea', 'Manhattan', 'Entire home/apt', 124)
# (1043046, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (1072481, 'Chelsea', 'Manhattan', 'Private room', 70)
# (1089240, 'Chelsea', 'Manhattan', 'Private room', 176)
# (1105845, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (1133296, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (1139851, 'Chelsea', 'Manhattan', 'Entire home/apt', 90)
# (1182187, 'Chelsea', 'Manhattan', 'Private room', 125)
# (1292428, 'Chelsea', 'Manhattan', 'Private room', 119)
# (1336223, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (1336230, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (1336390, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (1377820, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (1408914, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (1421933, 'Chelsea', 'Manhattan', 'Private room', 90)
# (1478946, 'Chelsea', 'Manhattan', 'Entire home/apt', 98)
# (1479283, 'Chelsea', 'Manhattan', 'Entire home/apt', 96)
# (1524017, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (1701981, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (1704798, 'Chelsea', 'Manhattan', 'Private room', 76)
# (1752206, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (1759526, 'Chelsea', 'Manhattan', 'Private room', 90)
# (1811446, 'Chelsea', 'Manhattan', 'Private room', 90)
# (1820858, 'Chelsea', 'Manhattan', 'Entire home/apt', 161)
# (1835367, 'Chelsea', 'Manhattan', 'Entire home/apt', 92)
# (1866051, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (1871261, 'Chelsea', 'Manhattan', 'Private room', 90)
# (1891017, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (1892319, 'Chelsea', 'Manhattan', 'Private room', 84)
# (1903249, 'Chelsea', 'Manhattan', 'Private room', 75)
# (1947400, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (1975999, 'Chelsea', 'Manhattan', 'Entire home/apt', 189)
# (2071420, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (2093064, 'Chelsea', 'Manhattan', 'Entire home/apt', 139)
# (2134052, 'Chelsea', 'Manhattan', 'Entire home/apt', 90)
# (2185668, 'Chelsea', 'Manhattan', 'Private room', 80)
# (2186699, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (2310445, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (2422991, 'Chelsea', 'Manhattan', 'Entire home/apt', 159)
# (2493039, 'Chelsea', 'Manhattan', 'Private room', 119)
# (2723554, 'Chelsea', 'Manhattan', 'Entire home/apt', 110)
# (2756159, 'Chelsea', 'Manhattan', 'Shared room', 85)
# (2918732, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (3010430, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (3029690, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (3060297, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (3265409, 'Chelsea', 'Manhattan', 'Private room', 90)
# (3279671, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (3339205, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (3339273, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (3344509, 'Chelsea', 'Manhattan', 'Entire home/apt', 179)
# (3496384, 'Chelsea', 'Manhattan', 'Private room', 85)
# (3521162, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (3616946, 'Chelsea', 'Manhattan', 'Private room', 135)
# (3636601, 'Chelsea', 'Manhattan', 'Entire home/apt', 95)
# (3782283, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (3801701, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (3896579, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (3922417, 'Chelsea', 'Manhattan', 'Entire home/apt', 95)
# (3983422, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (4129195, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (4144849, 'Chelsea', 'Manhattan', 'Entire home/apt', 115)
# (4220151, 'Chelsea', 'Manhattan', 'Entire home/apt', 159)
# (4276618, 'Chelsea', 'Manhattan', 'Entire home/apt', 120)
# (4284031, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (4297952, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (4329728, 'Chelsea', 'Manhattan', 'Private room', 110)
# (4338177, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (4431247, 'Chelsea', 'Manhattan', 'Shared room', 70)
# (4509500, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (4841187, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (4842507, 'Chelsea', 'Manhattan', 'Private room', 150)
# (4920912, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (4930306, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (5160871, 'Chelsea', 'Manhattan', 'Entire home/apt', 135)
# (5298299, 'Chelsea', 'Manhattan', 'Private room', 109)
# (5334478, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (5401148, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (5661080, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (5872177, 'Chelsea', 'Manhattan', 'Entire home/apt', 163)
# (5958299, 'Chelsea', 'Manhattan', 'Private room', 105)
# (6128992, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (6262496, 'Chelsea', 'Manhattan', 'Private room', 150)
# (6402807, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (6478214, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (6479559, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (6543312, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (6590569, 'Chelsea', 'Manhattan', 'Private room', 110)
# (6645224, 'Chelsea', 'Manhattan', 'Private room', 100)
# (6674363, 'Chelsea', 'Manhattan', 'Private room', 130)
# (6692975, 'Chelsea', 'Manhattan', 'Private room', 100)
# (6730056, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (6737815, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (6748933, 'Chelsea', 'Manhattan', 'Entire home/apt', 145)
# (6831518, 'Chelsea', 'Manhattan', 'Private room', 99)
# (6853271, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (6908209, 'Chelsea', 'Manhattan', 'Entire home/apt', 155)
# (6949104, 'Chelsea', 'Manhattan', 'Private room', 135)
# (6965441, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (7275273, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (7292891, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (7364374, 'Chelsea', 'Manhattan', 'Private room', 150)
# (7483034, 'Chelsea', 'Manhattan', 'Private room', 195)
# (7563529, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (7603389, 'Chelsea', 'Manhattan', 'Private room', 118)
# (7758577, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (7760406, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (7859723, 'Chelsea', 'Manhattan', 'Entire home/apt', 120)
# (7881023, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (7969111, 'Chelsea', 'Manhattan', 'Private room', 135)
# (7981341, 'Chelsea', 'Manhattan', 'Shared room', 200)
# (8014087, 'Chelsea', 'Manhattan', 'Private room', 100)
# (8045421, 'Chelsea', 'Manhattan', 'Entire home/apt', 129)
# (8145339, 'Chelsea', 'Manhattan', 'Entire home/apt', 129)
# (8210423, 'Chelsea', 'Manhattan', 'Private room', 95)
# (8342053, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (8368794, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (8388776, 'Chelsea', 'Manhattan', 'Entire home/apt', 109)
# (8519400, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (8541831, 'Chelsea', 'Manhattan', 'Entire home/apt', 116)
# (8698671, 'Chelsea', 'Manhattan', 'Private room', 112)
# (8742567, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (8988997, 'Chelsea', 'Manhattan', 'Entire home/apt', 129)
# (8989430, 'Chelsea', 'Manhattan', 'Entire home/apt', 136)
# (9003691, 'Chelsea', 'Manhattan', 'Entire home/apt', 109)
# (9127011, 'Chelsea', 'Manhattan', 'Entire home/apt', 193)
# (9144999, 'Chelsea', 'Manhattan', 'Private room', 140)
# (9155475, 'Chelsea', 'Manhattan', 'Entire home/apt', 130)
# (9175459, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (9183131, 'Chelsea', 'Manhattan', 'Private room', 139)
# (9201479, 'Chelsea', 'Manhattan', 'Private room', 100)
# (9299515, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (9365502, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (9394266, 'Chelsea', 'Manhattan', 'Private room', 100)
# (9401453, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (9463039, 'Chelsea', 'Manhattan', 'Entire home/apt', 182)
# (9464543, 'Chelsea', 'Manhattan', 'Private room', 98)
# (9496094, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (9505268, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (9525241, 'Chelsea', 'Manhattan', 'Entire home/apt', 126)
# (9540974, 'Chelsea', 'Manhattan', 'Private room', 195)
# (9585339, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (9609825, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (9740386, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (9772152, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (9862831, 'Chelsea', 'Manhattan', 'Entire home/apt', 80)
# (9865374, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (9881516, 'Chelsea', 'Manhattan', 'Private room', 50)
# (9885815, 'Chelsea', 'Manhattan', 'Entire home/apt', 85)
# (9940966, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (10037605, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (10059699, 'Chelsea', 'Manhattan', 'Entire home/apt', 159)
# (10090735, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (10096773, 'Chelsea', 'Manhattan', 'Entire home/apt', 145)
# (10148581, 'Chelsea', 'Manhattan', 'Private room', 52)
# (10210556, 'Chelsea', 'Manhattan', 'Private room', 175)
# (10322621, 'Chelsea', 'Manhattan', 'Private room', 81)
# (10403231, 'Chelsea', 'Manhattan', 'Entire home/apt', 120)
# (10452737, 'Chelsea', 'Manhattan', 'Private room', 139)
# (10482237, 'Chelsea', 'Manhattan', 'Private room', 85)
# (10482409, 'Chelsea', 'Manhattan', 'Private room', 85)
# (10482554, 'Chelsea', 'Manhattan', 'Private room', 85)
# (10489896, 'Chelsea', 'Manhattan', 'Shared room', 46)
# (10564375, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (10692885, 'Chelsea', 'Manhattan', 'Entire home/apt', 120)
# (10766309, 'Chelsea', 'Manhattan', 'Private room', 130)
# (10903055, 'Chelsea', 'Manhattan', 'Private room', 119)
# (10904914, 'Chelsea', 'Manhattan', 'Private room', 70)
# (11006134, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (11296590, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (11389773, 'Chelsea', 'Manhattan', 'Private room', 65)
# (11419133, 'Chelsea', 'Manhattan', 'Private room', 80)
# (11453784, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (11503335, 'Chelsea', 'Manhattan', 'Private room', 84)
# (11531154, 'Chelsea', 'Manhattan', 'Private room', 70)
# (11563821, 'Chelsea', 'Manhattan', 'Private room', 110)
# (11863468, 'Chelsea', 'Manhattan', 'Entire home/apt', 142)
# (12000030, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (12050280, 'Chelsea', 'Manhattan', 'Private room', 150)
# (12067652, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (12089661, 'Chelsea', 'Manhattan', 'Private room', 175)
# (12167152, 'Chelsea', 'Manhattan', 'Private room', 179)
# (12171671, 'Chelsea', 'Manhattan', 'Private room', 85)
# (12322923, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (12355067, 'Chelsea', 'Manhattan', 'Private room', 200)
# (12560942, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (12658099, 'Chelsea', 'Manhattan', 'Private room', 100)
# (12681730, 'Chelsea', 'Manhattan', 'Private room', 125)
# (12772993, 'Chelsea', 'Manhattan', 'Private room', 55)
# (12786165, 'Chelsea', 'Manhattan', 'Private room', 75)
# (12825700, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (12854724, 'Chelsea', 'Manhattan', 'Entire home/apt', 75)
# (12854734, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (12869561, 'Chelsea', 'Manhattan', 'Entire home/apt', 191)
# (12884594, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (12891996, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (12989612, 'Chelsea', 'Manhattan', 'Private room', 100)
# (12989767, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (13044689, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (13078166, 'Chelsea', 'Manhattan', 'Entire home/apt', 179)
# (13115864, 'Chelsea', 'Manhattan', 'Entire home/apt', 105)
# (13162066, 'Chelsea', 'Manhattan', 'Entire home/apt', 130)
# (13169806, 'Chelsea', 'Manhattan', 'Entire home/apt', 154)
# (13186741, 'Chelsea', 'Manhattan', 'Private room', 85)
# (13252064, 'Chelsea', 'Manhattan', 'Shared room', 75)
# (13415535, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (13476685, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (13494898, 'Chelsea', 'Manhattan', 'Entire home/apt', 110)
# (13514387, 'Chelsea', 'Manhattan', 'Private room', 90)
# (13613052, 'Chelsea', 'Manhattan', 'Private room', 70)
# (13642631, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (13695031, 'Chelsea', 'Manhattan', 'Entire home/apt', 155)
# (13723345, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (13746962, 'Chelsea', 'Manhattan', 'Private room', 150)
# (13752222, 'Chelsea', 'Manhattan', 'Private room', 135)
# (13757845, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (13926604, 'Chelsea', 'Manhattan', 'Private room', 85)
# (13926664, 'Chelsea', 'Manhattan', 'Private room', 85)
# (13953224, 'Chelsea', 'Manhattan', 'Entire home/apt', 190)
# (14041141, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (14057678, 'Chelsea', 'Manhattan', 'Private room', 125)
# (14108509, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (14108671, 'Chelsea', 'Manhattan', 'Private room', 90)
# (14120431, 'Chelsea', 'Manhattan', 'Entire home/apt', 155)
# (14155064, 'Chelsea', 'Manhattan', 'Entire home/apt', 143)
# (14236416, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (14312186, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (14429513, 'Chelsea', 'Manhattan', 'Private room', 139)
# (14609804, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (14821494, 'Chelsea', 'Manhattan', 'Entire home/apt', 129)
# (14858544, 'Chelsea', 'Manhattan', 'Entire home/apt', 90)
# (14887025, 'Chelsea', 'Manhattan', 'Entire home/apt', 109)
# (15021783, 'Chelsea', 'Manhattan', 'Private room', 80)
# (15083267, 'Chelsea', 'Manhattan', 'Private room', 110)
# (15141938, 'Chelsea', 'Manhattan', 'Private room', 180)
# (15252848, 'Chelsea', 'Manhattan', 'Entire home/apt', 110)
# (15282411, 'Chelsea', 'Manhattan', 'Private room', 120)
# (15314886, 'Chelsea', 'Manhattan', 'Entire home/apt', 179)
# (15323284, 'Chelsea', 'Manhattan', 'Private room', 110)
# (15446631, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (15520060, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (15625556, 'Chelsea', 'Manhattan', 'Private room', 78)
# (15664673, 'Chelsea', 'Manhattan', 'Private room', 120)
# (15773659, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (15927071, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (15937164, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (16002841, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (16032177, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (16103920, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (16107664, 'Chelsea', 'Manhattan', 'Entire home/apt', 181)
# (16120794, 'Chelsea', 'Manhattan', 'Entire home/apt', 156)
# (16170544, 'Chelsea', 'Manhattan', 'Entire home/apt', 60)
# (16172895, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (16228505, 'Chelsea', 'Manhattan', 'Private room', 120)
# (16253465, 'Chelsea', 'Manhattan', 'Entire home/apt', 128)
# (16274292, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (16336497, 'Chelsea', 'Manhattan', 'Entire home/apt', 110)
# (16393191, 'Chelsea', 'Manhattan', 'Private room', 85)
# (16393395, 'Chelsea', 'Manhattan', 'Private room', 85)
# (16405036, 'Chelsea', 'Manhattan', 'Private room', 95)
# (16440192, 'Chelsea', 'Manhattan', 'Private room', 85)
# (16506579, 'Chelsea', 'Manhattan', 'Private room', 85)
# (16529755, 'Chelsea', 'Manhattan', 'Private room', 115)
# (16543032, 'Chelsea', 'Manhattan', 'Entire home/apt', 196)
# (16828843, 'Chelsea', 'Manhattan', 'Entire home/apt', 130)
# (16874685, 'Chelsea', 'Manhattan', 'Private room', 200)
# (16945093, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (16976215, 'Chelsea', 'Manhattan', 'Private room', 125)
# (17071462, 'Chelsea', 'Manhattan', 'Private room', 99)
# (17223109, 'Chelsea', 'Manhattan', 'Entire home/apt', 190)
# (17237486, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (17297014, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (17344027, 'Chelsea', 'Manhattan', 'Private room', 103)
# (17360353, 'Chelsea', 'Manhattan', 'Private room', 100)
# (17368006, 'Chelsea', 'Manhattan', 'Private room', 82)
# (17543905, 'Chelsea', 'Manhattan', 'Private room', 100)
# (17555918, 'Chelsea', 'Manhattan', 'Private room', 90)
# (17584136, 'Chelsea', 'Manhattan', 'Entire home/apt', 190)
# (17610059, 'Chelsea', 'Manhattan', 'Private room', 100)
# (17752493, 'Chelsea', 'Manhattan', 'Private room', 89)
# (17762525, 'Chelsea', 'Manhattan', 'Entire home/apt', 139)
# (17905479, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (17981447, 'Chelsea', 'Manhattan', 'Private room', 57)
# (18024772, 'Chelsea', 'Manhattan', 'Entire home/apt', 95)
# (18034890, 'Chelsea', 'Manhattan', 'Private room', 105)
# (18050153, 'Chelsea', 'Manhattan', 'Entire home/apt', 134)
# (18124043, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (18173989, 'Chelsea', 'Manhattan', 'Private room', 69)
# (18288371, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (18386307, 'Chelsea', 'Manhattan', 'Entire home/apt', 89)
# (18481196, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (18579416, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (18584180, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (18812670, 'Chelsea', 'Manhattan', 'Private room', 68)
# (18849349, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (18892465, 'Chelsea', 'Manhattan', 'Private room', 150)
# (18933994, 'Chelsea', 'Manhattan', 'Private room', 90)
# (19015029, 'Chelsea', 'Manhattan', 'Private room', 85)
# (19098733, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (19218475, 'Chelsea', 'Manhattan', 'Private room', 90)
# (19249099, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (19313064, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (19364229, 'Chelsea', 'Manhattan', 'Private room', 100)
# (19368455, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (19385683, 'Chelsea', 'Manhattan', 'Private room', 130)
# (19408844, 'Chelsea', 'Manhattan', 'Entire home/apt', 135)
# (19415979, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (19439790, 'Chelsea', 'Manhattan', 'Entire home/apt', 189)
# (19455149, 'Chelsea', 'Manhattan', 'Private room', 49)
# (19455656, 'Chelsea', 'Manhattan', 'Private room', 65)
# (19563669, 'Chelsea', 'Manhattan', 'Private room', 140)
# (19573919, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (19609919, 'Chelsea', 'Manhattan', 'Private room', 105)
# (19619159, 'Chelsea', 'Manhattan', 'Entire home/apt', 155)
# (19622470, 'Chelsea', 'Manhattan', 'Private room', 100)
# (19652739, 'Chelsea', 'Manhattan', 'Entire home/apt', 130)
# (19714903, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (19790344, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (19821160, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (19821206, 'Chelsea', 'Manhattan', 'Entire home/apt', 128)
# (19968961, 'Chelsea', 'Manhattan', 'Private room', 110)
# (20133862, 'Chelsea', 'Manhattan', 'Entire home/apt', 169)
# (20182193, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (20204055, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (20250864, 'Chelsea', 'Manhattan', 'Private room', 40)
# (20350538, 'Chelsea', 'Manhattan', 'Entire home/apt', 164)
# (20425394, 'Chelsea', 'Manhattan', 'Entire home/apt', 162)
# (20506481, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (20587567, 'Chelsea', 'Manhattan', 'Entire home/apt', 154)
# (20651136, 'Chelsea', 'Manhattan', 'Private room', 165)
# (20722247, 'Chelsea', 'Manhattan', 'Private room', 75)
# (20815900, 'Chelsea', 'Manhattan', 'Private room', 89)
# (20860184, 'Chelsea', 'Manhattan', 'Private room', 95)
# (20864878, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (20941420, 'Chelsea', 'Manhattan', 'Private room', 100)
# (21015751, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (21044271, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (21121441, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (21181643, 'Chelsea', 'Manhattan', 'Private room', 99)
# (21185183, 'Chelsea', 'Manhattan', 'Entire home/apt', 169)
# (21213047, 'Chelsea', 'Manhattan', 'Entire home/apt', 165)
# (21215073, 'Chelsea', 'Manhattan', 'Private room', 149)
# (21215200, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (21254023, 'Chelsea', 'Manhattan', 'Private room', 110)
# (21306332, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (21413839, 'Chelsea', 'Manhattan', 'Private room', 82)
# (21428231, 'Chelsea', 'Manhattan', 'Private room', 95)
# (21452348, 'Chelsea', 'Manhattan', 'Entire home/apt', 128)
# (21469886, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (21475999, 'Chelsea', 'Manhattan', 'Private room', 85)
# (21682816, 'Chelsea', 'Manhattan', 'Private room', 120)
# (21718049, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (21767672, 'Chelsea', 'Manhattan', 'Entire home/apt', 159)
# (21771502, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (21838658, 'Chelsea', 'Manhattan', 'Private room', 99)
# (21844377, 'Chelsea', 'Manhattan', 'Private room', 200)
# (21851700, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (21861551, 'Chelsea', 'Manhattan', 'Private room', 155)
# (21893604, 'Chelsea', 'Manhattan', 'Private room', 12)
# (21937451, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (21995883, 'Chelsea', 'Manhattan', 'Private room', 150)
# (22106002, 'Chelsea', 'Manhattan', 'Private room', 99)
# (22143436, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (22144662, 'Chelsea', 'Manhattan', 'Entire home/apt', 109)
# (22164078, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (22232463, 'Chelsea', 'Manhattan', 'Entire home/apt', 135)
# (22241573, 'Chelsea', 'Manhattan', 'Private room', 115)
# (22303856, 'Chelsea', 'Manhattan', 'Entire home/apt', 152)
# (22312190, 'Chelsea', 'Manhattan', 'Private room', 84)
# (22352793, 'Chelsea', 'Manhattan', 'Entire home/apt', 110)
# (22353899, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (22361598, 'Chelsea', 'Manhattan', 'Entire home/apt', 159)
# (22550483, 'Chelsea', 'Manhattan', 'Private room', 88)
# (22628471, 'Chelsea', 'Manhattan', 'Entire home/apt', 75)
# (22651509, 'Chelsea', 'Manhattan', 'Entire home/apt', 115)
# (22683927, 'Chelsea', 'Manhattan', 'Private room', 150)
# (22754110, 'Chelsea', 'Manhattan', 'Entire home/apt', 115)
# (22781825, 'Chelsea', 'Manhattan', 'Entire home/apt', 75)
# (22944203, 'Chelsea', 'Manhattan', 'Private room', 84)
# (23001249, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (23131463, 'Chelsea', 'Manhattan', 'Entire home/apt', 127)
# (23166556, 'Chelsea', 'Manhattan', 'Private room', 63)
# (23258639, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (23344243, 'Chelsea', 'Manhattan', 'Entire home/apt', 146)
# (23374229, 'Chelsea', 'Manhattan', 'Private room', 98)
# (23421363, 'Chelsea', 'Manhattan', 'Private room', 80)
# (23464702, 'Chelsea', 'Manhattan', 'Private room', 99)
# (23468785, 'Chelsea', 'Manhattan', 'Private room', 80)
# (23514583, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (23548260, 'Chelsea', 'Manhattan', 'Entire home/apt', 96)
# (23560164, 'Chelsea', 'Manhattan', 'Entire home/apt', 186)
# (23632578, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (23765706, 'Chelsea', 'Manhattan', 'Entire home/apt', 172)
# (23839939, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (23855466, 'Chelsea', 'Manhattan', 'Entire home/apt', 70)
# (24080143, 'Chelsea', 'Manhattan', 'Private room', 89)
# (24266025, 'Chelsea', 'Manhattan', 'Private room', 70)
# (24312275, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (24377683, 'Chelsea', 'Manhattan', 'Private room', 85)
# (24393653, 'Chelsea', 'Manhattan', 'Private room', 190)
# (24715838, 'Chelsea', 'Manhattan', 'Entire home/apt', 190)
# (24866257, 'Chelsea', 'Manhattan', 'Private room', 175)
# (24894724, 'Chelsea', 'Manhattan', 'Entire home/apt', 120)
# (24992418, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (25156498, 'Chelsea', 'Manhattan', 'Private room', 75)
# (25259845, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (25292558, 'Chelsea', 'Manhattan', 'Private room', 100)
# (25340844, 'Chelsea', 'Manhattan', 'Private room', 68)
# (25355845, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (25380189, 'Chelsea', 'Manhattan', 'Private room', 100)
# (25380654, 'Chelsea', 'Manhattan', 'Private room', 99)
# (25516958, 'Chelsea', 'Manhattan', 'Entire home/apt', 179)
# (25752683, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (26658854, 'Chelsea', 'Manhattan', 'Private room', 50)
# (26805133, 'Chelsea', 'Manhattan', 'Private room', 92)
# (26812606, 'Chelsea', 'Manhattan', 'Entire home/apt', 69)
# (26934498, 'Chelsea', 'Manhattan', 'Private room', 150)
# (27085372, 'Chelsea', 'Manhattan', 'Entire home/apt', 98)
# (27100997, 'Chelsea', 'Manhattan', 'Private room', 115)
# (27112835, 'Chelsea', 'Manhattan', 'Entire home/apt', 85)
# (27140232, 'Chelsea', 'Manhattan', 'Entire home/apt', 155)
# (27160493, 'Chelsea', 'Manhattan', 'Private room', 165)
# (27185508, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (27199508, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (27333579, 'Chelsea', 'Manhattan', 'Private room', 120)
# (27372891, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (27527118, 'Chelsea', 'Manhattan', 'Private room', 77)
# (27551268, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (27600437, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (27654829, 'Chelsea', 'Manhattan', 'Private room', 200)
# (27802387, 'Chelsea', 'Manhattan', 'Shared room', 85)
# (27853549, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (27903413, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (28104895, 'Chelsea', 'Manhattan', 'Entire home/apt', 167)
# (28133007, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (28335031, 'Chelsea', 'Manhattan', 'Entire home/apt', 154)
# (28359765, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (28372451, 'Chelsea', 'Manhattan', 'Entire home/apt', 110)
# (28440536, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (28715589, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (28752251, 'Chelsea', 'Manhattan', 'Private room', 91)
# (28754650, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (28832811, 'Chelsea', 'Manhattan', 'Private room', 90)
# (28881114, 'Chelsea', 'Manhattan', 'Private room', 175)
# (28919308, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (28964081, 'Chelsea', 'Manhattan', 'Entire home/apt', 137)
# (28964397, 'Chelsea', 'Manhattan', 'Private room', 65)
# (28981827, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (29063993, 'Chelsea', 'Manhattan', 'Entire home/apt', 69)
# (29381358, 'Chelsea', 'Manhattan', 'Private room', 165)
# (29384622, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (29393808, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (29440688, 'Chelsea', 'Manhattan', 'Private room', 100)
# (29630728, 'Chelsea', 'Manhattan', 'Entire home/apt', 189)
# (29701500, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (29780863, 'Chelsea', 'Manhattan', 'Private room', 180)
# (29904741, 'Chelsea', 'Manhattan', 'Private room', 85)
# (29906273, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (29945246, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (30062478, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (30108247, 'Chelsea', 'Manhattan', 'Private room', 114)
# (30133439, 'Chelsea', 'Manhattan', 'Private room', 66)
# (30137792, 'Chelsea', 'Manhattan', 'Private room', 85)
# (30182093, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (30199043, 'Chelsea', 'Manhattan', 'Private room', 150)
# (30227667, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (30272473, 'Chelsea', 'Manhattan', 'Entire home/apt', 139)
# (30445028, 'Chelsea', 'Manhattan', 'Private room', 110)
# (30563760, 'Chelsea', 'Manhattan', 'Private room', 138)
# (30708899, 'Chelsea', 'Manhattan', 'Private room', 133)
# (30709202, 'Chelsea', 'Manhattan', 'Private room', 130)
# (30769959, 'Chelsea', 'Manhattan', 'Private room', 138)
# (30788330, 'Chelsea', 'Manhattan', 'Entire home/apt', 160)
# (30824786, 'Chelsea', 'Manhattan', 'Private room', 75)
# (30885792, 'Chelsea', 'Manhattan', 'Private room', 80)
# (31054566, 'Chelsea', 'Manhattan', 'Private room', 68)
# (31122807, 'Chelsea', 'Manhattan', 'Private room', 200)
# (31122836, 'Chelsea', 'Manhattan', 'Private room', 200)
# (31151736, 'Chelsea', 'Manhattan', 'Entire home/apt', 190)
# (31297452, 'Chelsea', 'Manhattan', 'Entire home/apt', 190)
# (31382878, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (31390350, 'Chelsea', 'Manhattan', 'Private room', 100)
# (31489863, 'Chelsea', 'Manhattan', 'Private room', 92)
# (31543550, 'Chelsea', 'Manhattan', 'Private room', 86)
# (31622417, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (31654063, 'Chelsea', 'Manhattan', 'Private room', 99)
# (31748621, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (31883514, 'Chelsea', 'Manhattan', 'Private room', 99)
# (31883774, 'Chelsea', 'Manhattan', 'Private room', 99)
# (32113235, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (32163602, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (32164433, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (32172621, 'Chelsea', 'Manhattan', 'Private room', 99)
# (32189288, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (32449378, 'Chelsea', 'Manhattan', 'Shared room', 180)
# (32549565, 'Chelsea', 'Manhattan', 'Entire home/apt', 139)
# (32549617, 'Chelsea', 'Manhattan', 'Entire home/apt', 123)
# (32663202, 'Chelsea', 'Manhattan', 'Shared room', 65)
# (32668900, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (32675979, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676082, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676180, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676181, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676185, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676186, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676189, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32676190, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32678246, 'Chelsea', 'Manhattan', 'Private room', 100)
# (32691375, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (32748646, 'Chelsea', 'Manhattan', 'Private room', 80)
# (32763453, 'Chelsea', 'Manhattan', 'Private room', 150)
# (32764575, 'Chelsea', 'Manhattan', 'Private room', 140)
# (32773207, 'Chelsea', 'Manhattan', 'Entire home/apt', 149)
# (32805038, 'Chelsea', 'Manhattan', 'Entire home/apt', 139)
# (32885270, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (33069506, 'Chelsea', 'Manhattan', 'Private room', 83)
# (33113990, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (33142839, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (33189664, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (33226326, 'Chelsea', 'Manhattan', 'Entire home/apt', 140)
# (33270883, 'Chelsea', 'Manhattan', 'Private room', 100)
# (33294631, 'Chelsea', 'Manhattan', 'Private room', 75)
# (33295329, 'Chelsea', 'Manhattan', 'Entire home/apt', 120)
# (33365859, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (33571687, 'Chelsea', 'Manhattan', 'Entire home/apt', 170)
# (33595791, 'Chelsea', 'Manhattan', 'Private room', 115)
# (33608666, 'Chelsea', 'Manhattan', 'Private room', 110)
# (33708931, 'Chelsea', 'Manhattan', 'Private room', 150)
# (33712513, 'Chelsea', 'Manhattan', 'Entire home/apt', 154)
# (33719823, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (33745548, 'Chelsea', 'Manhattan', 'Private room', 99)
# (33745550, 'Chelsea', 'Manhattan', 'Private room', 199)
# (33850135, 'Chelsea', 'Manhattan', 'Entire home/apt', 162)
# (33866860, 'Chelsea', 'Manhattan', 'Entire home/apt', 99)
# (33874579, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (33935442, 'Chelsea', 'Manhattan', 'Private room', 130)
# (33981416, 'Chelsea', 'Manhattan', 'Private room', 110)
# (33998274, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (34019440, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (34042658, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (34196510, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34198108, 'Chelsea', 'Manhattan', 'Private room', 129)
# (34206163, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34206654, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34206709, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34206762, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34206858, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34206929, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34207022, 'Chelsea', 'Manhattan', 'Private room', 129)
# (34207413, 'Chelsea', 'Manhattan', 'Private room', 149)
# (34207474, 'Chelsea', 'Manhattan', 'Private room', 149)
# (34207544, 'Chelsea', 'Manhattan', 'Private room', 149)
# (34207635, 'Chelsea', 'Manhattan', 'Private room', 149)
# (34207673, 'Chelsea', 'Manhattan', 'Private room', 159)
# (34207739, 'Chelsea', 'Manhattan', 'Private room', 159)
# (34207862, 'Chelsea', 'Manhattan', 'Private room', 159)
# (34255740, 'Chelsea', 'Manhattan', 'Entire home/apt', 134)
# (34284883, 'Chelsea', 'Manhattan', 'Entire home/apt', 129)
# (34338645, 'Chelsea', 'Manhattan', 'Private room', 85)
# (34341588, 'Chelsea', 'Manhattan', 'Entire home/apt', 159)
# (34343752, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (34383329, 'Chelsea', 'Manhattan', 'Private room', 85)
# (34446902, 'Chelsea', 'Manhattan', 'Private room', 140)
# (34470949, 'Chelsea', 'Manhattan', 'Private room', 109)
# (34470950, 'Chelsea', 'Manhattan', 'Private room', 199)
# (34470954, 'Chelsea', 'Manhattan', 'Private room', 159)
# (34675093, 'Chelsea', 'Manhattan', 'Entire home/apt', 100)
# (34866413, 'Chelsea', 'Manhattan', 'Entire home/apt', 93)
# (34929016, 'Chelsea', 'Manhattan', 'Private room', 89)
# (35114837, 'Chelsea', 'Manhattan', 'Entire home/apt', 154)
# (35166718, 'Chelsea', 'Manhattan', 'Private room', 120)
# (35228980, 'Chelsea', 'Manhattan', 'Entire home/apt', 199)
# (35236040, 'Chelsea', 'Manhattan', 'Private room', 150)
# (35315680, 'Chelsea', 'Manhattan', 'Entire home/apt', 195)
# (35342841, 'Chelsea', 'Manhattan', 'Entire home/apt', 180)
# (35384734, 'Chelsea', 'Manhattan', 'Entire home/apt', 198)
# (35497792, 'Chelsea', 'Manhattan', 'Private room', 105)
# (35646737, 'Chelsea', 'Manhattan', 'Private room', 85)
# (35707367, 'Chelsea', 'Manhattan', 'Entire home/apt', 175)
# (35754614, 'Chelsea', 'Manhattan', 'Entire home/apt', 200)
# (35790090, 'Chelsea', 'Manhattan', 'Entire home/apt', 89)
# (35971673, 'Chelsea', 'Manhattan', 'Private room', 105)
# (35971885, 'Chelsea', 'Manhattan', 'Private room', 105)
# (36060576, 'Chelsea', 'Manhattan', 'Entire home/apt', 125)
# (36112469, 'Chelsea', 'Manhattan', 'Entire home/apt', 185)
# (36223408, 'Chelsea', 'Manhattan', 'Private room', 150)
# (36227884, 'Chelsea', 'Manhattan', 'Shared room', 67)
# (36280357, 'Chelsea', 'Manhattan', 'Entire home/apt', 150)
# (36281050, 'Chelsea', 'Manhattan', 'Entire home/apt', 181)
# (36302523, 'Chelsea', 'Manhattan', 'Entire home/apt', 109)
# (36320933, 'Chelsea', 'Manhattan', 'Shared room', 75)
# (36409084, 'Chelsea', 'Manhattan', 'Shared room', 75)
# (36439761, 'Chelsea', 'Manhattan', 'Entire home/apt', 155)

# %% [markdown]
# # Section 4: Closing the Database Connection <a name="closing-connection"></a>

# %% [markdown]
# ### Task 4.1: Close the Cursor and Database Connection
# - It's good practice to close the cursor and the database connection when you're done working with the database to free up system resources and maintain proper connection management.

# %%
# Completed
# Make sure to include these lines of code at the end of your script to properly close the cursor and database connection.
cursor.close()
conn.close()

# %% [markdown]
# # Section 5: Summary of Basic SQL Commands <a name="summary-commands"></a>

# %% [markdown]
# In this project, you have practiced various SQL commands and tasks. Below is a summary of the basic SQL commands used:
#
# **Task 1.2: Connect to the Database**
# - Established a connection to the SQLite database.
#
# **Task 2.1: Load the Dataset**
# - Loaded the dataset into a DataFrame.
# - Imported the DataFrame into the database.
#
# **Task 3.1: Retrieve all Columns**
# - Executed a SELECT query to retrieve all columns.
#
# **Task 3.2: Count Total Records**
# - Executed a SELECT COUNT(*) query to count the total records.
#
# **Task 3.3: Top 10 Neighborhoods by Average Price**
# - Executed a SELECT query with GROUP BY, ORDER BY, and LIMIT clauses.
#
# **Task 3.4: Number of Listings by Room Type**
# - Executed a SELECT query with COUNT() and GROUP BY.
#
# **Task 3.5: Average Number of Reviews per Listing**
# - Executed a SELECT query with AVG().
#
# **Task 3.6: Listings with Minimum Number of Reviews**
# - Executed a SELECT query with WHERE and a subquery.
#
# **Task 3.7: Filter Listings by Neighborhood and Maximum Price**
# - Executed a SELECT query with WHERE conditions.
#
# **Task 4.1: Close the Cursor and Database Connection**
# - Closed the cursor and the database connection.
#
# This summary provides an overview of the basic SQL commands used in this project. You can use this as a reference for future SQL projects and data analysis tasks.

# %% [markdown]
# <h3 align = 'center' >
# Thank you for completing the project!
# </h3>
#
# Please do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
#
# Please send your completed Google Colab Notebook to the NSDC HQ Team at nsdc@nebigdatahub.org in order to receive your virtual certificate of completion.
